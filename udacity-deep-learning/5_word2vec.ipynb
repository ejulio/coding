# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5240, 3083, 12, 6, 195, 2, 3136, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

print(data[:10])
for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
# [5240, 3083, 12, 6, 195, 2, 3136, 46, 59, 156]
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'a', 'originated', 'term', 'term', 'as', 'originated', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.215721
# Nearest to that: inquisitor, diverges, overlay, alto, tomahawk, affiliates, boromir, threat,
# Nearest to states: whistling, bigcup, housewives, obstructed, circulation, arcy, howe, paleontology,
# Nearest to with: prostaglandins, cofactors, bahadur, primus, monorail, uneconomic, grey, khz,
# Nearest to one: lonergan, hokku, abidjan, rohypnol, wheel, sunday, ascertain, blogger,
# Nearest to most: clout, labs, foobar, engagement, solver, vicki, replicate, mooted,
# Nearest to people: presidents, specifies, sampras, nw, mar, weaken, karzai, monitored,
# Nearest to in: vdp, purifying, putin, legis, mongol, degas, whaling, panel,
# Nearest to of: sundance, aerodynamics, petition, spurred, philosophies, hans, devastated, scholarship,
# Nearest to history: crossings, moderating, mdf, mauser, targum, monaghan, sly, bah,
# Nearest to be: hockey, gadol, casas, cared, started, finding, grained, popularity,
# Nearest to b: scare, alford, commuting, cusp, rose, vernal, moves, fast,
# Nearest to so: hira, nasrallah, transceiver, dicaprio, invite, candidate, picturesque, dol,
# Nearest to was: reversal, malayan, legislatures, slides, amit, buckminster, compl, sul,
# Nearest to these: fresco, tolerable, sizes, match, eventually, dv, farthest, mel,
# Nearest to but: malfunctions, bracelets, bourgeoisie, wishing, alekhine, scanners, sons, prohibits,
# Nearest to he: whittaker, impetuous, bronze, knox, mock, albion, lamarck, sopranos,
# Average loss at step 2000: 4.368860
# Average loss at step 4000: 3.867275
# Average loss at step 6000: 3.782837
# Average loss at step 8000: 3.687500
# Average loss at step 10000: 3.617663
# Nearest to that: which, this, wm, it, motto, barbed, diverges, normed,
# Nearest to states: housewives, whistling, bangladesh, obstructed, types, bigcup, paleontology, existed,
# Nearest to with: in, brane, lugo, by, into, from, for, woodrow,
# Nearest to one: two, three, seven, six, four, eight, offline, iota,
# Nearest to most: replicate, mooted, solver, using, labs, vg, cations, bland,
# Nearest to people: laterals, presidents, oau, specifies, weathering, whitcomb, trianon, niall,
# Nearest to in: of, on, with, at, from, upc, between, irresponsibility,
# Nearest to of: in, dummies, same, shellfish, and, volumes, for, cartographer,
# Nearest to history: pentatonic, ethics, botanists, describes, thessalian, romans, mauser, monaghan,
# Nearest to be: have, was, due, is, been, toolkit, up, gluck,
# Nearest to b: scare, cusp, alford, legume, willem, fast, hell, klein,
# Nearest to so: picturesque, seamstress, andromache, snapshot, dol, hira, natives, kaluza,
# Nearest to was: is, has, by, had, were, be, became, been,
# Nearest to these: teleport, fresco, daemon, match, such, chamada, anglian, dv,
# Nearest to but: wishing, deceleration, samaritans, scanners, which, bourgeoisie, however, and,
# Nearest to he: it, they, she, who, dominates, impetuous, there, falk,
# Average loss at step 12000: 3.605586
# Average loss at step 14000: 3.572683
# Average loss at step 16000: 3.409516
# Average loss at step 18000: 3.457847
# Average loss at step 20000: 3.539009
# Nearest to that: which, however, soaring, this, but, tley, miletus, normed,
# Nearest to states: housewives, whistling, existed, obstructed, bangladesh, types, howe, paleontology,
# Nearest to with: by, in, for, between, into, amundsen, from, daugavpils,
# Nearest to one: two, three, four, seven, five, eight, six, nine,
# Nearest to most: more, replicate, solver, using, misrepresented, mooted, some, many,
# Nearest to people: laterals, oau, cod, robots, whitcomb, vcr, curled, trianon,
# Nearest to in: at, on, from, between, during, with, for, by,
# Nearest to of: same, under, for, original, shellfish, eritreans, dummies, splendid,
# Nearest to history: botanists, ethics, romans, thessalian, western, definitively, describes, kind,
# Nearest to be: have, been, was, take, is, by, were, being,
# Nearest to b: d, polymers, cusp, antoine, abuser, willem, conquering, rose,
# Nearest to so: picturesque, snapshot, orgy, putney, ventricle, kaluza, thrax, ethene,
# Nearest to was: is, has, had, were, be, became, are, did,
# Nearest to these: many, such, wolfman, they, some, several, all, which,
# Nearest to but: however, and, which, although, does, is, wishing, though,
# Nearest to he: it, she, they, who, there, dominates, then, falk,
# Average loss at step 22000: 3.499786
# Average loss at step 24000: 3.489652
# Average loss at step 26000: 3.483379
# Average loss at step 28000: 3.480113
# Average loss at step 30000: 3.509374
# Nearest to that: which, however, whether, what, worldstatesmen, this, because, tley,
# Nearest to states: existed, nations, housewives, whistling, bangladesh, script, howe, types,
# Nearest to with: between, in, without, for, when, brane, from, shao,
# Nearest to one: two, seven, four, eight, three, nine, five, six,
# Nearest to most: more, some, misrepresented, many, els, mooted, replicate, requirements,
# Nearest to people: laterals, centrality, curled, oau, bor, vcr, whitcomb, robots,
# Nearest to in: during, at, of, on, between, upc, and, under,
# Nearest to of: in, and, cartographer, for, from, transmitters, dummies, including,
# Nearest to history: western, kind, ethics, botanists, describes, definitively, thessalian, period,
# Nearest to be: been, have, was, create, being, were, is, produce,
# Nearest to b: d, antoine, abuser, cusp, victoriae, polymers, klein, conquering,
# Nearest to so: ethene, putney, picturesque, ventricle, too, sedimentary, positivism, orgy,
# Nearest to was: is, were, had, has, became, been, be, when,
# Nearest to these: some, many, such, all, several, they, wolfman, their,
# Nearest to but: however, and, although, which, aardwolf, or, he, when,
# Nearest to he: it, she, they, who, there, but, unsuited, eventually,
# Average loss at step 32000: 3.504043
# Average loss at step 34000: 3.498837
# Average loss at step 36000: 3.451140
# Average loss at step 38000: 3.303495
# Average loss at step 40000: 3.426746
# Nearest to that: which, however, because, what, this, where, it, tley,
# Nearest to states: nations, kingdom, existed, forces, bangladesh, script, howe, battleship,
# Nearest to with: in, between, when, palatine, brane, by, for, divides,
# Nearest to one: seven, two, six, eight, five, four, nine, three,
# Nearest to most: more, many, some, misrepresented, els, less, moldavian, broadcast,
# Nearest to people: oau, rab, vcr, straight, weathering, bor, curled, centrality,
# Nearest to in: of, with, on, during, from, upc, until, for,
# Nearest to of: in, dummies, for, from, shellfish, aerodynamics, radiant, abet,
# Nearest to history: western, sommerfeld, thessalian, botanists, thinks, monolingual, blake, definitively,
# Nearest to be: have, been, is, was, create, are, being, were,
# Nearest to b: d, UNK, antoine, conquering, abuser, fast, victoriae, cruz,
# Nearest to so: ethene, putney, magnates, too, sedimentary, thrax, natives, sooner,
# Nearest to was: is, became, were, had, has, been, be, did,
# Nearest to these: many, some, several, such, both, they, their, all,
# Nearest to but: however, although, and, though, which, kryptonian, aardwolf, are,
# Nearest to he: she, it, they, who, there, i, dylan, unsuited,
# Average loss at step 42000: 3.433148
# Average loss at step 44000: 3.456300
# Average loss at step 46000: 3.446548
# Average loss at step 48000: 3.352144
# Average loss at step 50000: 3.379623
# Nearest to that: which, however, what, where, but, this, tley, calvinistic,
# Nearest to states: nations, kingdom, existed, bangladesh, howe, ldots, trapezohedron, carnivorous,
# Nearest to with: between, brane, alongside, by, compressed, baikonur, derivations, aleksandar,
# Nearest to one: two, eight, six, four, seven, three, nine, five,
# Nearest to most: more, many, some, less, misrepresented, els, moldavian, modelling,
# Nearest to people: children, laterals, centrality, students, curled, oau, retelling, vcr,
# Nearest to in: upc, since, financi, on, during, from, of, within,
# Nearest to of: in, and, cartographer, including, withhold, shellfish, for, aerodynamics,
# Nearest to history: sommerfeld, monolingual, geology, book, western, allyn, peake, botanists,
# Nearest to be: have, being, were, create, been, was, become, refer,
# Nearest to b: d, antoine, conquering, p, fast, bowls, herbalists, c,
# Nearest to so: then, ethene, sooner, magnates, qx, clump, reassignment, sedimentary,
# Nearest to was: is, were, has, became, had, been, be, by,
# Nearest to these: many, several, some, such, both, those, examples, they,
# Nearest to but: however, though, although, and, while, kryptonian, when, that,
# Nearest to he: she, it, they, who, there, this, dylan, then,
# Average loss at step 52000: 3.438334
# Average loss at step 54000: 3.427836
# Average loss at step 56000: 3.440232
# Average loss at step 58000: 3.396599
# Average loss at step 60000: 3.389678
# Nearest to that: which, what, however, this, it, wm, where, often,
# Nearest to states: nations, kingdom, countries, carnivorous, misinterpreted, armies, forces, existed,
# Nearest to with: between, when, by, baikonur, involving, dismal, brane, in,
# Nearest to one: two, eight, four, nine, six, three, seven, five,
# Nearest to most: many, more, some, less, misrepresented, use, all, moldavian,
# Nearest to people: children, centrality, curled, those, students, men, scientists, scholars,
# Nearest to in: during, within, since, upc, between, until, including, phenomenal,
# Nearest to of: for, in, dummies, like, shellfish, cartographer, transmitters, original,
# Nearest to history: geology, allyn, centre, peake, thessalian, list, sommerfeld, sprint,
# Nearest to be: been, become, produce, have, create, being, were, was,
# Nearest to b: d, p, c, h, f, antoine, herbalists, disjunctive,
# Nearest to so: then, ethene, too, sooner, magnates, clump, if, properly,
# Nearest to was: is, became, had, were, has, been, although, when,
# Nearest to these: many, several, some, such, those, all, their, both,
# Nearest to but: however, although, and, though, when, while, is, oo,
# Nearest to he: she, it, they, there, we, who, dylan, this,
# Average loss at step 62000: 3.240912
# Average loss at step 64000: 3.252966
# Average loss at step 66000: 3.402532
# Average loss at step 68000: 3.396096
# Average loss at step 70000: 3.359104
# Nearest to that: which, what, however, this, but, usually, wm, where,
# Nearest to states: nations, kingdom, countries, misinterpreted, state, armies, carnivorous, existed,
# Nearest to with: between, palatine, alongside, by, divides, dismal, brane, pops,
# Nearest to one: two, six, seven, eight, four, five, nine, three,
# Nearest to most: more, many, less, some, misrepresented, use, highly, rdos,
# Nearest to people: children, students, women, curled, centrality, scientists, those, men,
# Nearest to in: within, during, on, upc, since, for, at, until,
# Nearest to of: including, exact, shellfish, in, gastroenterology, dummies, for, include,
# Nearest to history: geology, list, period, peake, allyn, maradns, orderly, thessalian,
# Nearest to be: been, become, being, is, were, have, was, produce,
# Nearest to b: d, p, h, r, f, disjunctive, interceptions, cruz,
# Nearest to so: then, ethene, too, thus, clump, properly, picturesque, putney,
# Nearest to was: is, has, had, were, became, when, been, be,
# Nearest to these: many, such, several, some, those, are, all, various,
# Nearest to but: however, although, which, and, that, though, does, oo,
# Nearest to he: she, it, they, there, we, who, eventually, this,
# Average loss at step 72000: 3.366575
# Average loss at step 74000: 3.350769
# Average loss at step 76000: 3.314753
# Average loss at step 78000: 3.354892
# Average loss at step 80000: 3.376535
# Nearest to that: which, however, this, where, lame, wm, what, barbed,
# Nearest to states: nations, kingdom, countries, state, misinterpreted, armies, dominates, apparitions,
# Nearest to with: between, palatine, baikonur, into, by, brane, in, when,
# Nearest to one: two, seven, six, eight, five, three, four, nine,
# Nearest to most: more, many, some, less, misrepresented, moldavian, use, carrel,
# Nearest to people: children, students, men, women, retelling, residents, centrality, animals,
# Nearest to in: during, until, within, on, at, since, after, upc,
# Nearest to of: including, dummies, cartographer, in, stony, handwriting, transmitters, cohesion,
# Nearest to history: vil, graphic, bleachers, allyn, geology, list, centre, implementation,
# Nearest to be: been, being, have, is, become, was, were, lead,
# Nearest to b: d, r, interceptions, disjunctive, c, p, h, f,
# Nearest to so: then, ethene, clump, properly, too, peaceful, thus, if,
# Nearest to was: is, became, were, had, has, been, be, when,
# Nearest to these: several, many, those, both, such, various, all, are,
# Nearest to but: however, although, obscuring, and, while, kalat, see, or,
# Nearest to he: she, it, they, who, there, we, never, eventually,
# Average loss at step 82000: 3.409524
# Average loss at step 84000: 3.410754
# Average loss at step 86000: 3.391651
# Average loss at step 88000: 3.353893
# Average loss at step 90000: 3.367069
# Nearest to that: which, however, but, what, wm, lame, crashed, tley,
# Nearest to states: nations, kingdom, countries, state, misinterpreted, armies, cns, us,
# Nearest to with: between, palatine, in, alongside, by, christo, vibrant, when,
# Nearest to one: two, seven, eight, four, six, three, five, nine,
# Nearest to most: more, many, some, less, misrepresented, especially, moldavian, use,
# Nearest to people: children, students, women, residents, men, retelling, those, god,
# Nearest to in: within, during, under, upc, between, with, until, around,
# Nearest to of: cartographer, in, including, for, dummies, current, under, zarah,
# Nearest to history: list, bleachers, vil, graphic, allyn, geology, sowed, tradition,
# Nearest to be: been, being, was, is, become, produce, have, create,
# Nearest to b: d, c, h, disjunctive, interceptions, y, r, k,
# Nearest to so: too, ethene, thus, peaceful, clump, then, thoroughly, how,
# Nearest to was: is, had, became, were, be, has, been, being,
# Nearest to these: several, many, some, those, are, various, all, such,
# Nearest to but: however, and, although, while, though, that, or, until,
# Nearest to he: she, they, it, there, who, later, eventually, we,
# Average loss at step 92000: 3.399889
# Average loss at step 94000: 3.254958
# Average loss at step 96000: 3.360631
# Average loss at step 98000: 3.239559
# Average loss at step 100000: 3.357410
# Nearest to that: which, however, what, wm, but, spaceship, who, tley,
# Nearest to states: nations, kingdom, countries, state, misinterpreted, armies, titian, sapkowski,
# Nearest to with: between, alongside, including, by, using, within, palatine, involving,
# Nearest to one: two, seven, eight, four, five, nine, six, three,
# Nearest to most: more, less, many, especially, some, moldavian, highly, misrepresented,
# Nearest to people: children, students, women, men, things, retelling, jews, players,
# Nearest to in: during, within, on, until, upc, throughout, from, at,
# Nearest to of: including, in, original, and, makes, from, attributing, cartographer,
# Nearest to history: list, graphic, allyn, review, maradns, lefty, vil, sowed,
# Nearest to be: been, have, become, produce, being, is, are, refer,
# Nearest to b: d, reagan, antoine, bakassi, rubber, willem, bm, cruz,
# Nearest to so: thus, then, too, how, ethene, sooner, ultimately, clump,
# Nearest to was: is, became, had, were, has, although, been, when,
# Nearest to these: several, many, those, some, various, all, which, instead,
# Nearest to but: however, although, and, though, while, which, kalat, that,
# Nearest to he: she, it, they, there, who, we, never, eventually,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

# generate batches fro CBOW model
def generate_batch(batch_size, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window

  batch = np.ndarray(shape=(batch_size, skip_window * 2), dtype = np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype = np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen = span)
  
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)

  for i in range(batch_size):
    target = skip_window  # target label at the center of the buffer
    labels[i, 0] = buffer[target]
    j_index = 0
    for j in range(span):
      if j == target:
        continue
      batch[i, j_index] = buffer[j]
      j_index += 1
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
    
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for skip_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, skip_window=skip_window)
    print('\nwith skip_window = %d:' % (skip_window))
    print('    batch:', [';'.join([reverse_dictionary[ci] for ci in context]) for context in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with skip_window = 1:
#     batch: ['anarchism;as', 'originated;a', 'as;term', 'a;of', 'term;abuse', 'of;first', 'abuse;used', 'first;against']
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with skip_window = 2:
#     batch: ['anarchism;originated;a;term', 'originated;as;term;of', 'as;a;of;abuse', 'a;term;abuse;first', 'term;of;first;used', 'of;abuse;used;against', 'abuse;first;against;early', 'first;used;early;working']
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, 2 * skip_window])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = None
  for j in range(2 * skip_window):
    embedding_j = tf.nn.embedding_lookup(embeddings, train_dataset[:, j])
    (embed_height, embed_width) = embedding_j.shape.as_list()
    embedding_j = tf.reshape(embedding_j, [embed_height, embed_width, 1])
    if embed is None:
        embed = embedding_j
    else:
        embed = tf.concat([embed, embedding_j], 2)
        
  avg_embed = tf.reduce_mean(embed, axis = 2, keep_dims = False)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=avg_embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.540295
# Nearest to with: schwenkfeld, disbanded, nagasaki, cabal, tius, cradle, carbonated, kerguelen,
# Nearest to for: fertilizers, thyestes, gymnastics, bilaterally, nehru, monarch, assumed, firing,
# Nearest to nine: demand, hbo, curves, champagne, hierarchies, stative, prostate, brecht,
# Nearest to between: publicizing, fetal, lister, yeah, likely, unprovoked, hypoxic, expectancies,
# Nearest to many: lachaise, wasteful, heart, oblivion, essence, ppg, ub, movie,
# Nearest to a: tanakh, megan, footnote, somalis, convent, rtp, abroad, duality,
# Nearest to use: sightseeing, candlemas, pig, coke, coyotes, giraffe, individualist, pets,
# Nearest to as: norton, thymus, fin, desires, chamada, dharma, aortic, olga,
# Nearest to time: spitz, aichi, brig, quadra, coe, zbigniew, ges, ibadi,
# Nearest to which: linked, bernadette, pedestrians, guerrilla, inning, names, lays, minoan,
# Nearest to i: manageable, relaunch, donner, reductase, drip, josip, witt, veterinary,
# Nearest to will: maior, grandsons, notions, lithographs, clipping, tu, traffickers, repeats,
# Nearest to by: hawthorn, tetris, suzanne, slaughter, cardiology, icrm, questioning, sidewalk,
# Nearest to most: spades, k, tuireadh, saturation, mosiah, adamantly, jacobson, decisively,
# Nearest to on: algiers, measures, nephew, selassie, vacationing, ros, deeds, sixes,
# Nearest to about: definability, gpp, universitaire, ans, reductionism, eszterh, minnesota, raft,
# Average loss at step 2000: 4.039072
# Average loss at step 4000: 3.504220
# Average loss at step 6000: 3.340408
# Average loss at step 8000: 3.193574
# Average loss at step 10000: 3.144845
# Nearest to with: rothschild, between, under, scheme, loneliness, into, ceding, single,
# Nearest to for: when, specific, of, gymnastics, heller, grunt, nehru, adc,
# Nearest to nine: eight, six, seven, five, four, zero, three, two,
# Nearest to between: over, publicizing, maharaja, with, in, kenneth, expectancies, unprovoked,
# Nearest to many: some, several, lachaise, other, chechens, essence, all, most,
# Nearest to a: the, lionheart, somalis, any, coaches, tall, megan, jolla,
# Nearest to use: pig, kind, intel, candlemas, study, coke, hangman, pirates,
# Nearest to as: became, norton, pressure, into, thymus, myocardium, implanted, ecclesiae,
# Nearest to time: neh, surface, validity, ges, oxus, quadra, gbit, argos,
# Nearest to which: that, this, minoan, lays, messe, socialized, often, lendl,
# Nearest to i: donner, phonetics, tienne, veterinary, manageable, witt, phyllis, altay,
# Nearest to will: would, can, could, should, cannot, maior, may, wapping,
# Nearest to by: icrm, into, coprime, roses, samos, kite, fsln, diocesan,
# Nearest to most: bacon, scott, trailer, thermoregulation, aims, decisively, jacobson, many,
# Nearest to on: broch, in, nephew, at, crts, bianchi, converts, algiers,
# Nearest to about: gtpase, fairs, geneticist, using, disintegration, definability, catapulted, ans,
# Average loss at step 12000: 3.172978
# Average loss at step 14000: 3.129830
# Average loss at step 16000: 3.148013
# Average loss at step 18000: 3.106508
# Average loss at step 20000: 2.993834
# Nearest to with: between, ceding, rothschild, single, under, pagans, schwenkfeld, misheard,
# Nearest to for: when, affliction, astrolabe, callaghan, nehru, sensing, tannenberg, grunt,
# Nearest to nine: eight, six, seven, five, four, three, zero, javascript,
# Nearest to between: with, over, along, maharaja, publicizing, expectancies, ide, barter,
# Nearest to many: some, several, most, other, those, these, lachaise, chechens,
# Nearest to a: the, another, any, somalis, hellish, healed, jolla, megan,
# Nearest to use: kind, pig, candlemas, study, hangman, intel, utf, economically,
# Nearest to as: became, thymus, norton, hegelians, orinoco, canarian, rios, projections,
# Nearest to time: neh, validity, surface, quadra, way, ges, gbit, peacefully,
# Nearest to which: that, this, lays, who, minoan, symptom, socialized, approximating,
# Nearest to i: you, phonetics, ii, tienne, we, she, donner, altay,
# Nearest to will: would, can, could, should, cannot, must, may, might,
# Nearest to by: icrm, samos, rabbit, roses, fsln, be, into, diocesan,
# Nearest to most: more, less, many, thermoregulation, bacon, trailer, voc, skeptic,
# Nearest to on: upon, broch, in, at, liter, bisected, algiers, nephew,
# Nearest to about: using, definability, geneticist, gtpase, disintegration, sequences, oecd, cpi,
# Average loss at step 22000: 3.054576
# Average loss at step 24000: 3.026163
# Average loss at step 26000: 2.990505
# Average loss at step 28000: 3.016845
# Average loss at step 30000: 2.989148
# Nearest to with: between, rothschild, ceding, under, scheme, steadfastly, entire, jabber,
# Nearest to for: affliction, habitual, when, without, asset, deviant, specific, astrolabe,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to between: with, over, along, publicizing, ide, maharaja, barter, expectancies,
# Nearest to many: some, several, other, such, those, most, these, various,
# Nearest to a: any, another, the, every, somalis, jolla, nauru, megan,
# Nearest to use: kind, pig, study, hangman, chambers, give, candlemas, crises,
# Nearest to as: together, angelina, norton, magie, intimate, ecclesiae, miranda, mtr,
# Nearest to time: neh, way, validity, quadra, oxus, surface, game, paige,
# Nearest to which: that, this, typically, who, what, usually, skylark, also,
# Nearest to i: ii, you, phonetics, we, tienne, she, altay, extracellular,
# Nearest to will: would, could, can, cannot, must, may, should, might,
# Nearest to by: through, icrm, samos, rabbit, thracian, roses, fsln, diocesan,
# Nearest to most: more, less, many, some, thermoregulation, voc, cataract, tuireadh,
# Nearest to on: upon, broch, at, in, assuming, creeks, crts, liter,
# Nearest to about: using, definability, geneticist, gtpase, sequences, oecd, cpi, macrostate,
# Average loss at step 32000: 2.844955
# Average loss at step 34000: 2.946307
# Average loss at step 36000: 2.934411
# Average loss at step 38000: 2.938533
# Average loss at step 40000: 2.916615
# Nearest to with: between, ceding, steadfastly, frost, rothschild, contends, into, by,
# Nearest to for: when, affliction, habitual, deviant, after, tannenberg, beautifully, ribs,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to between: with, along, over, among, strengths, publicizing, maharaja, ide,
# Nearest to many: some, several, most, various, those, other, both, these,
# Nearest to a: another, workstation, the, healed, somalis, any, misinterpreted, gardener,
# Nearest to use: kind, pig, chambers, hangman, crises, palermo, give, study,
# Nearest to as: angelina, norton, miranda, globin, recanted, ecclesiae, became, mtr,
# Nearest to time: validity, neh, game, quadra, oxus, peacefully, way, surface,
# Nearest to which: that, this, what, typically, usually, these, approximating, often,
# Nearest to i: ii, you, we, phonetics, she, tienne, UNK, iii,
# Nearest to will: would, could, can, cannot, may, must, should, might,
# Nearest to by: icrm, through, samos, diocesan, thracian, roses, during, hawthorn,
# Nearest to most: more, less, some, many, thermoregulation, voc, yamato, several,
# Nearest to on: upon, broch, in, horizontal, crts, baba, liter, assuming,
# Nearest to about: using, geneticist, gtpase, cpi, definability, sequences, macrostate, oecd,
# Average loss at step 42000: 2.937455
# Average loss at step 44000: 2.942034
# Average loss at step 46000: 2.902564
# Average loss at step 48000: 2.869543
# Average loss at step 50000: 2.844833
# Nearest to with: between, steadfastly, estas, advert, rothschild, ceding, under, frost,
# Nearest to for: when, habitual, adc, while, astrolabe, boomerangs, without, affliction,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to between: with, along, over, among, within, ide, maharaja, publicizing,
# Nearest to many: some, several, various, most, these, all, those, katydids,
# Nearest to a: another, the, any, every, lionheart, shaku, antipopes, workstation,
# Nearest to use: kind, treatment, palermo, chambers, excess, pig, compress, crises,
# Nearest to as: angelina, intimate, mtr, hegelians, canarian, etudes, miranda, orinoco,
# Nearest to time: peacefully, validity, neh, haskell, gbit, deployment, oxus, esiason,
# Nearest to which: that, this, typically, what, usually, these, approximating, also,
# Nearest to i: we, you, ii, phonetics, iii, tienne, she, iv,
# Nearest to will: would, could, can, cannot, may, must, should, might,
# Nearest to by: through, icrm, roses, during, samos, thracian, towards, ut,
# Nearest to most: more, less, some, many, especially, thermoregulation, several, dcsd,
# Nearest to on: upon, broch, crts, liter, horizontal, bianchi, regarding, in,
# Nearest to about: definability, gtpase, macrostate, cpi, oecd, using, geneticist, suarez,
# Average loss at step 52000: 2.886217
# Average loss at step 54000: 2.860376
# Average loss at step 56000: 2.858105
# Average loss at step 58000: 2.765546
# Average loss at step 60000: 2.828123
# Nearest to with: between, containing, estas, including, under, among, rothschild, within,
# Nearest to for: when, without, habitual, fan, ayres, ribs, affliction, asset,
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Nearest to between: with, along, among, over, within, ide, strengths, publicizing,
# Nearest to many: some, several, various, those, most, all, these, few,
# Nearest to a: another, the, any, somalis, workstation, every, shaku, enough,
# Nearest to use: treatment, hangman, kind, excess, cyclist, chambers, crises, flung,
# Nearest to as: angelina, mtr, rios, recanted, hegelians, atzeret, orinoco, because,
# Nearest to time: validity, peacefully, neh, oxus, quadra, gbit, courses, way,
# Nearest to which: that, this, what, typically, approximating, these, usually, but,
# Nearest to i: we, you, ii, phonetics, tienne, iii, iv, she,
# Nearest to will: would, could, can, cannot, must, may, should, might,
# Nearest to by: through, roses, icrm, fsln, during, reginae, samos, towards,
# Nearest to most: more, some, less, many, especially, aymara, yamato, several,
# Nearest to on: upon, broch, in, bianchi, around, through, crts, at,
# Nearest to about: definability, regarding, geneticist, over, cpi, macrostate, gtpase, ishikawa,
# Average loss at step 62000: 2.831005
# Average loss at step 64000: 2.778690
# Average loss at step 66000: 2.770094
# Average loss at step 68000: 2.715854
# Average loss at step 70000: 2.775680
# Nearest to with: between, under, steadfastly, estas, when, including, among, ceding,
# Nearest to for: housekeeper, against, habitual, affliction, without, tax, tannenberg, when,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to between: with, among, within, along, over, around, during, ide,
# Nearest to many: some, several, various, those, most, all, both, few,
# Nearest to a: another, the, any, every, healed, workstation, shaku, coaches,
# Nearest to use: treatment, kind, hangman, passage, excess, cyclist, crises, success,
# Nearest to as: hegelians, angelina, mtr, intimate, when, recanted, magie, cartographers,
# Nearest to time: peacefully, courses, neh, gbit, quadra, mound, oxus, validity,
# Nearest to which: that, typically, this, what, usually, these, also, actually,
# Nearest to i: we, you, ii, iii, phonetics, tienne, iv, repercussions,
# Nearest to will: would, could, can, must, cannot, should, may, might,
# Nearest to by: through, icrm, during, diocesan, roses, reginae, toward, fsln,
# Nearest to most: more, less, many, some, especially, dcsd, largo, voc,
# Nearest to on: upon, in, broch, liter, inside, around, horizontal, bianchi,
# Nearest to about: definability, oecd, regarding, macrostate, geneticist, cpi, over, gtpase,
# Average loss at step 72000: 2.798914
# Average loss at step 74000: 2.661749
# Average loss at step 76000: 2.801029
# Average loss at step 78000: 2.823048
# Average loss at step 80000: 2.783765
# Nearest to with: between, including, estas, ceding, containing, rumford, via, in,
# Nearest to for: when, after, habitual, while, housekeeper, fontana, without, adc,
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Nearest to between: with, among, along, within, around, over, ide, during,
# Nearest to many: several, some, various, those, most, all, few, both,
# Nearest to a: another, the, workstation, shaku, every, any, positioned, succinctly,
# Nearest to use: treatment, hagar, cyclist, kind, hangman, excess, passage, success,
# Nearest to as: angelina, canarian, hegelians, when, recanted, orinoco, globin, mtr,
# Nearest to time: peacefully, day, month, gbit, neh, mound, validity, oxus,
# Nearest to which: that, this, what, these, typically, instead, approximating, usually,
# Nearest to i: you, we, ii, iii, they, phonetics, she, tienne,
# Nearest to will: would, could, can, must, should, cannot, may, might,
# Nearest to by: during, through, icrm, roses, diocesan, towards, fsln, under,
# Nearest to most: more, many, less, some, especially, several, euro, dcsd,
# Nearest to on: upon, broch, in, inside, around, at, under, supports,
# Nearest to about: over, definability, regarding, geneticist, cpi, jul, persecutions, excommunicate,
# Average loss at step 82000: 2.675759
# Average loss at step 84000: 2.775742
# Average loss at step 86000: 2.741248
# Average loss at step 88000: 2.758233
# Average loss at step 90000: 2.747466
# Nearest to with: between, including, among, steadfastly, via, ceding, cv, uppermost,
# Nearest to for: when, affliction, boomerangs, habitual, krone, after, distorts, ribs,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to between: with, among, within, along, during, over, ide, tract,
# Nearest to many: several, some, various, most, those, numerous, few, all,
# Nearest to a: another, the, any, credited, poitou, coaches, lawlessness, every,
# Nearest to use: kind, trace, treatment, hagar, excess, cyclist, hangman, linus,
# Nearest to as: angelina, mtr, hegelians, etudes, intimate, manatee, canarian, cartographers,
# Nearest to time: peacefully, day, month, gbit, mound, neh, courses, oxus,
# Nearest to which: that, this, what, typically, instead, these, approximating, actually,
# Nearest to i: we, you, ii, iii, they, iv, she, phonetics,
# Nearest to will: would, could, can, must, may, should, cannot, might,
# Nearest to by: through, icrm, roses, towards, sprawling, using, somaliland, toward,
# Nearest to most: more, many, some, less, especially, several, all, correspondents,
# Nearest to on: upon, in, broch, inside, through, around, supports, within,
# Nearest to about: over, regarding, cpi, persecutions, gtpase, definability, suarez, oecd,
# Average loss at step 92000: 2.690563
# Average loss at step 94000: 2.730686
# Average loss at step 96000: 2.709252
# Average loss at step 98000: 2.386338
# Average loss at step 100000: 2.419812
# Nearest to with: between, steadfastly, via, bradshaw, compl, towards, estas, contends,
# Nearest to for: after, when, fan, against, during, beautifully, sensing, amongst,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to between: among, with, within, along, garret, yum, around, publicizing,
# Nearest to many: several, some, various, numerous, those, few, most, all,
# Nearest to a: another, the, shaku, healed, poitou, lawlessness, workstation, reservoirs,
# Nearest to use: kind, trace, treatment, hangman, hagar, excess, crises, cause,
# Nearest to as: angelina, mtr, etudes, analyzes, became, intimate, canarian, hegelians,
# Nearest to time: peacefully, mound, oxus, neh, gbit, courses, week, month,
# Nearest to which: that, what, this, typically, instead, also, actually, who,
# Nearest to i: we, you, ii, iii, iv, they, she, tienne,
# Nearest to will: would, could, can, should, must, may, cannot, might,
# Nearest to by: through, icrm, toward, when, without, towards, during, with,
# Nearest to most: more, less, some, many, especially, several, aymara, correspondents,
# Nearest to on: upon, broch, endpin, bianchi, inside, at, tooth, regarding,
# Nearest to about: over, regarding, definability, retaining, jul, persecutions, suarez, cpi,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
